# %% [markdown]
# MODULES & PACKAGES
#
# # MOdularity
# - modular design - create diffent modules
#
# # Reusability
# - use an already written piece of code again & again

# %% [markdown]
# ## MODULE
# - a single file: like single python script (a set of functions)
#
# ## PACKAGE
# - a folder that holds multiple related files together
# - multiple modules can exist in a package
# - we use pip package of python in order to install a library
# for eg.
# pip install requests pillow numpy pandas
#
# ## LIBRARIES
# - 'Libraries' are packages that we can install and use
# - collection of packages & modules
# - requests : use to connect to internet
# - numpy
#
# # __init__ vs __main__
# - main file: is the entry point to the package | contains the functions to start the package/program
# - init file: mark a package for python to think of it as an official package | when importing a package it will run automatically when the package being executed

# %%
import test_project.greet as greeting
# Out:
# Hello Hariz, to this world
# Hello Idrees, to this world
# Hello Nomie, to this world

# %%
from test_project import greet

greet.evening()
# Out:
# Good Evening, salamat petang Othello

# %%
from nomie_lib import greet
from nomie_lib import nomie_arthematic as na

num1 = int(input("Enter a number: "))
num2 = int(input("Enter aanother number: "))

na.sum(num1, num2)

na.mul(num1, num2)
# Out:
# 'I am not a calculator. Go Learn some Multiplication: 77'

# %%
### Assignment : Micro School Mgmt System Project

Discussion:
- what things shd be there?

Requirements:
- Website : for school to be visible
- Records: 
--> info of every person involved - teachers, students, staff, security, chef, janitor / can hv diff role & responsibilities / diff data that is important

- Record update: get records, modify records, delete records

- Data Analysis of the data we are saving in database
- Adding other code for new things that are happening
- there can be much much more

Guidance:
1. Creating a folder - Package : name it properly using Camel Case preference
2. Problem Scoping/Statement - is where you decide what to achieve
    - also the part decides what not to Discussion
    - create diff classes for diff role in the school
    - 




Folder - Package
M

## Architecture
__init__.py : will run auto when we import Package
__main__.py : 
models.py : model
manager.py : view & controller - view things & can


--> the architecure using here is MVP (model view controller)

# %%
import SchoolManagementSystem as SMS
# Out:
# School Management System Initialized
