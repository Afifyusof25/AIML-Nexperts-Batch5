# %%
import pandas as pd

# %%
df = pd.read_csv("wc_2026.csv")

df.head()
df.tail()
df.sample(5)
# Out:
#    group          stage   team1   team2         venue       city country  \
# 99   NaN  Quarter-final     QF7     QF8   NRG Stadium    Houston     USA
# 9      B    Group Stage  Canada   Qatar      BC Place  Vancouver  Canada
# 74   NaN    Round of 32      1C      2D   NRG Stadium    Houston     USA
# 34     F    Group Stage   Japan  Sweden  AT&T Stadium  Arlington     USA
# 90   NaN    Round of 16  R32 W5  R32 W6     Rose Bowl   Pasadena     USA
#
#           date kickoff_et team1_confederation  team1_fifa_rank  \
# 99  2026-07-11        TBD                 NaN              NaN
# 9   2026-06-19   18:00 ET            CONCACAF             30.0
# 74  2026-06-29        TBD                 NaN              NaN
# 34  2026-06-26   15:00 ET                 AFC             18.0
# 90  2026-07-05        TBD                 NaN              NaN
#
#         team1_coach team2_confederation  team2_fifa_rank        team2_coach
# ...

# %%
df.shape # (104, 15)
df.size # 1560

df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   group                72 non-null     object
#  1   stage                104 non-null    object
#  2   team1                104 non-null    object
#  3   team2                104 non-null    object
#  4   venue                104 non-null    object
#  5   city                 104 non-null    object
#  6   country              104 non-null    object
#  7   date                 104 non-null    object
#  8   kickoff_et           104 non-null    object
#  9   team1_confederation  72 non-null     object
#  10  team1_fifa_rank      72 non-null     float64
#  11  team1_coach          72 non-null     object
#  12  team2_confederation  72 non-null     object
#  13  team2_fifa_rank      72 non-null     float64
#  14  team2_coach          72 non-null     object
# ...

# %%
## Filtering
# - filter rows & cols
# - using boolean indexing
# - keeps only the rows that we need
# - df[condition] or df[mask]

# %%
df.head()
# Out:
#   group        stage        team1         team2           venue         city  \
# 0     A  Group Stage       Mexico  South Africa  Estadio Azteca  Mexico City
# 1     A  Group Stage  South Korea       Czechia   Estadio Akron  Guadalajara
# 2     A  Group Stage  South Korea        Mexico   Estadio Akron  Guadalajara
# 3     A  Group Stage      Czechia  South Africa   Estadio Akron  Guadalajara
# 4     A  Group Stage      Czechia        Mexico  Estadio Azteca  Mexico City
#
#   country        date kickoff_et team1_confederation  team1_fifa_rank  \
# 0  Mexico  2026-06-11   20:00 ET            CONCACAF             15.0
# 1  Mexico  2026-06-11   22:00 ET                 AFC             25.0
# 2  Mexico  2026-06-18   21:00 ET                 AFC             25.0
# 3  Mexico  2026-06-18   18:00 ET                UEFA             41.0
# 4  Mexico  2026-06-24   21:00 ET                UEFA             41.0
#
#       team1_coach team2_confederation  team2_fifa_rank     team2_coach
# ...

# %%
## to show the matches played in Canada

mask = df["country"] == "Canada"
df[mask]
# Out:
#    group        stage                   team1                   team2  \
# 6      B  Group Stage                  Canada  Bosnia and Herzegovina
# 8      B  Group Stage             Switzerland  Bosnia and Herzegovina
# 9      B  Group Stage                  Canada                   Qatar
# 10     B  Group Stage             Switzerland                  Canada
# 11     B  Group Stage  Bosnia and Herzegovina                   Qatar
# 67     L  Group Stage                   Ghana                  Panama
# 69     L  Group Stage                 Croatia                  Panama
# 83   NaN  Round of 32                      1L                      2K
# 84   NaN  Round of 32             Best 3rd #1             Best 3rd #2
#
#         venue       city country        date kickoff_et team1_confederation  \
# 6   BMO Field    Toronto  Canada  2026-06-12   15:00 ET            CONCACAF
# 8    BC Place  Vancouver  Canada  2026-06-18   15:00 ET                UEFA
# ...

# %%
df[df['country'] == 'Canada']
# Out:
#    group        stage                   team1                   team2  \
# 6      B  Group Stage                  Canada  Bosnia and Herzegovina
# 8      B  Group Stage             Switzerland  Bosnia and Herzegovina
# 9      B  Group Stage                  Canada                   Qatar
# 10     B  Group Stage             Switzerland                  Canada
# 11     B  Group Stage  Bosnia and Herzegovina                   Qatar
# 67     L  Group Stage                   Ghana                  Panama
# 69     L  Group Stage                 Croatia                  Panama
# 83   NaN  Round of 32                      1L                      2K
# 84   NaN  Round of 32             Best 3rd #1             Best 3rd #2
#
#         venue       city country        date kickoff_et team1_confederation  \
# 6   BMO Field    Toronto  Canada  2026-06-12   15:00 ET            CONCACAF
# 8    BC Place  Vancouver  Canada  2026-06-18   15:00 ET                UEFA
# ...

# %%
## exercise 2: data for the matches team1_fifa rank was <=10

mask = df["team1_fifa_rank"] <=10

df[mask]
# Out:
#    group        stage        team1         team2                    venue  \
# 12     C  Group Stage       Brazil       Morocco          MetLife Stadium
# 14     C  Group Stage       Brazil      Scotland          MetLife Stadium
# 15     C  Group Stage      Morocco         Haiti          MetLife Stadium
# 17     C  Group Stage      Morocco         Haiti         Gillette Stadium
# 24     E  Group Stage      Germany       Curaçao              NRG Stadium
# 26     E  Group Stage      Germany   Ivory Coast              NRG Stadium
# 30     F  Group Stage  Netherlands         Japan             AT&T Stadium
# 32     F  Group Stage  Netherlands        Sweden              NRG Stadium
# 36     G  Group Stage      Belgium         Egypt              Lumen Field
# 38     G  Group Stage      Belgium          Iran             SoFi Stadium
# 42     H  Group Stage        Spain    Cape Verde    Mercedes-Benz Stadium
# 44     H  Group Stage        Spain  Saudi Arabia            Estadio Akron
# ...

# %%
## exercise 2: data for the matches team1_fifa rank was <=10

df[df["team1_fifa_rank"] <=10]
# Out:
#    group        stage        team1         team2                    venue  \
# 12     C  Group Stage       Brazil       Morocco          MetLife Stadium
# 14     C  Group Stage       Brazil      Scotland          MetLife Stadium
# 15     C  Group Stage      Morocco         Haiti          MetLife Stadium
# 17     C  Group Stage      Morocco         Haiti         Gillette Stadium
# 24     E  Group Stage      Germany       Curaçao              NRG Stadium
# 26     E  Group Stage      Germany   Ivory Coast              NRG Stadium
# 30     F  Group Stage  Netherlands         Japan             AT&T Stadium
# 32     F  Group Stage  Netherlands        Sweden              NRG Stadium
# 36     G  Group Stage      Belgium         Egypt              Lumen Field
# 38     G  Group Stage      Belgium          Iran             SoFi Stadium
# 42     H  Group Stage        Spain    Cape Verde    Mercedes-Benz Stadium
# 44     H  Group Stage        Spain  Saudi Arabia            Estadio Akron
# ...

# %%
## exercise 3: data for the matches both teams rank was <10

mask = (df["team1_fifa_rank"] <10) & (df["team2_fifa_rank"] <10)

df[(df["team1_fifa_rank"] <10) & (df["team2_fifa_rank"] <10)]
# Out:
#    group        stage   team1    team2            venue             city  \
# 12     C  Group Stage  Brazil  Morocco  MetLife Stadium  East Rutherford
#
#    country        date kickoff_et team1_confederation  team1_fifa_rank  \
# 12     USA  2026-06-13   18:00 ET            CONMEBOL              6.0
#
#        team1_coach team2_confederation  team2_fifa_rank     team2_coach
# 12  Dorival Júnior                 CAF              8.0  Walid Regragui

# %%
## exercise 3: data for the matches both teams rank was <10

df[(df["team1_fifa_rank"] <10) & (df["team2_fifa_rank"] <10)]
# Out:
#    group        stage   team1    team2            venue             city  \
# 12     C  Group Stage  Brazil  Morocco  MetLife Stadium  East Rutherford
#
#    country        date kickoff_et team1_confederation  team1_fifa_rank  \
# 12     USA  2026-06-13   18:00 ET            CONMEBOL              6.0
#
#        team1_coach team2_confederation  team2_fifa_rank     team2_coach
# 12  Dorival Júnior                 CAF              8.0  Walid Regragui

# %%
## exercise 4: Find all matches where Mexico is playing, specifically as team1 AND the venue is "Estadio Azteca"

mask = (df["team1"] == "Mexico") & (df["venue"] == "Estadio Azteca")
df[mask]
# Out:
#   group        stage   team1         team2           venue         city  \
# 0     A  Group Stage  Mexico  South Africa  Estadio Azteca  Mexico City
#
#   country        date kickoff_et team1_confederation  team1_fifa_rank  \
# 0  Mexico  2026-06-11   20:00 ET            CONCACAF             15.0
#
#       team1_coach team2_confederation  team2_fifa_rank team2_coach
# 0  Javier Aguirre                 CAF             60.0  Hugo Broos

# %%
## exercise 4: Find all matches where Mexico is playing, specifically as team1 AND the venue is "Estadio Azteca"

df[(df["team1"] == "Mexico") & (df["venue"] == "Estadio Azteca")]
# Out:
#   group        stage   team1         team2           venue         city  \
# 0     A  Group Stage  Mexico  South Africa  Estadio Azteca  Mexico City
#
#   country        date kickoff_et team1_confederation  team1_fifa_rank  \
# 0  Mexico  2026-06-11   20:00 ET            CONCACAF             15.0
#
#       team1_coach team2_confederation  team2_fifa_rank team2_coach
# 0  Javier Aguirre                 CAF             60.0  Hugo Broos

# %%
## exercise 5: Find all matches played in either "Toronto" or "Vancouver"

mask = (df["city"] == "Toronto") | (df["city"] == "Vancouver")
df[mask]
# Out:
#    group        stage                   team1                   team2  \
# 6      B  Group Stage                  Canada  Bosnia and Herzegovina
# 8      B  Group Stage             Switzerland  Bosnia and Herzegovina
# 9      B  Group Stage                  Canada                   Qatar
# 10     B  Group Stage             Switzerland                  Canada
# 11     B  Group Stage  Bosnia and Herzegovina                   Qatar
# 67     L  Group Stage                   Ghana                  Panama
# 69     L  Group Stage                 Croatia                  Panama
# 83   NaN  Round of 32                      1L                      2K
# 84   NaN  Round of 32             Best 3rd #1             Best 3rd #2
#
#         venue       city country        date kickoff_et team1_confederation  \
# 6   BMO Field    Toronto  Canada  2026-06-12   15:00 ET            CONCACAF
# 8    BC Place  Vancouver  Canada  2026-06-18   15:00 ET                UEFA
# ...

# %%
## exercise 5: Find all matches played in either "Toronto" or "Vancouver"

df[(df["city"] == "Toronto") | (df["city"] == "Vancouver")]
# Out:
#    group        stage                   team1                   team2  \
# 6      B  Group Stage                  Canada  Bosnia and Herzegovina
# 8      B  Group Stage             Switzerland  Bosnia and Herzegovina
# 9      B  Group Stage                  Canada                   Qatar
# 10     B  Group Stage             Switzerland                  Canada
# 11     B  Group Stage  Bosnia and Herzegovina                   Qatar
# 67     L  Group Stage                   Ghana                  Panama
# 69     L  Group Stage                 Croatia                  Panama
# 83   NaN  Round of 32                      1L                      2K
# 84   NaN  Round of 32             Best 3rd #1             Best 3rd #2
#
#         venue       city country        date kickoff_et team1_confederation  \
# 6   BMO Field    Toronto  Canada  2026-06-12   15:00 ET            CONCACAF
# 8    BC Place  Vancouver  Canada  2026-06-18   15:00 ET                UEFA
# ...

# %%
## exercise 5: Find all matches played in either "Toronto" or "Vancouver"

df[(df["city"] == "Toronto") | (df["city"] == "Vancouver")].shape # to know the total
# Out:
# (9, 15)

# %%
## exercise 6: Find all matches where:
# - team1 is ranked better than team2 AND
# - match either in Mexico or Canada

mask =  (
    (df["team1_fifa_rank"] < df["team2_fifa_rank"]) &
    (
        (df["country"] == "Mexico") |
        (df["country"] == "Canada")))

df[mask]
# Out:
#    group        stage        team1                   team2           venue  \
# 0      A  Group Stage       Mexico            South Africa  Estadio Azteca
# 1      A  Group Stage  South Korea                 Czechia   Estadio Akron
# 3      A  Group Stage      Czechia            South Africa   Estadio Akron
# 6      B  Group Stage       Canada  Bosnia and Herzegovina       BMO Field
# 8      B  Group Stage  Switzerland  Bosnia and Herzegovina        BC Place
# 9      B  Group Stage       Canada                   Qatar        BC Place
# 10     B  Group Stage  Switzerland                  Canada        BC Place
# 31     F  Group Stage       Sweden                 Tunisia    Estadio BBVA
# 44     H  Group Stage        Spain            Saudi Arabia   Estadio Akron
# 69     L  Group Stage      Croatia                  Panama       BMO Field
#
#            city country        date kickoff_et team1_confederation  \
# 0   Mexico City  Mexico  2026-06-11   20:00 ET            CONCACAF
# ...

# %%
## exercise 6: Find all matches where:
# - team1 is ranked better than team2 AND
# - match either in Mexico or Canada

df[(df["team1_fifa_rank"] < df["team2_fifa_rank"]) &
    ((df["country"] == "Mexico") | (df["country"] == "Canada"))]
# Out:
#    group        stage        team1                   team2           venue  \
# 0      A  Group Stage       Mexico            South Africa  Estadio Azteca
# 1      A  Group Stage  South Korea                 Czechia   Estadio Akron
# 3      A  Group Stage      Czechia            South Africa   Estadio Akron
# 6      B  Group Stage       Canada  Bosnia and Herzegovina       BMO Field
# 8      B  Group Stage  Switzerland  Bosnia and Herzegovina        BC Place
# 9      B  Group Stage       Canada                   Qatar        BC Place
# 10     B  Group Stage  Switzerland                  Canada        BC Place
# 31     F  Group Stage       Sweden                 Tunisia    Estadio BBVA
# 44     H  Group Stage        Spain            Saudi Arabia   Estadio Akron
# 69     L  Group Stage      Croatia                  Panama       BMO Field
#
#            city country        date kickoff_et team1_confederation  \
# 0   Mexico City  Mexico  2026-06-11   20:00 ET            CONCACAF
# ...

# %%
## exercise 6: Find all matches where:
# - team1 is ranked better than team2 AND
# - match either in Mexico or Canada

df[(df["team1_fifa_rank"] < df["team2_fifa_rank"]) &
    ((df["country"] == "Mexico") | (df["country"] == "Canada"))].shape
# Out:
# (10, 15)

# %%
## exercise 6: Find all matches where:
# - team1 is ranked better than team2 AND
# - match either in Mexico or Canada

# Drop all missing values
# Row with a single NaN value --- is dropped
# df.dropna(inplace = True) # Original will be affected

# df.info()

# give me an aggregate for the two columns
df[['team1_fifa_rank', 'team2_fifa_rank']].min(axis = 0)
# Out:
# team1_fifa_rank    1.0
# team2_fifa_rank    1.0
# dtype: float64

# %%
# give me an aggregate for the all the 72 rows
df[['team1_fifa_rank', 'team2_fifa_rank']].min(axis = 1)
# Out:
# 0     15.0
# 1     25.0
# 2     15.0
# 3     41.0
# 4     15.0
#       ...
# 67    53.0
# 68     4.0
# 69    11.0
# 70     4.0
# 71    11.0
# Length: 72, dtype: float64

# %%
df['team2_fifa_rank'].agg(['mean','min','max', 'count', 'std', 'var', 'prod'])
# Out:
# mean      3.791667e+01
# min       1.000000e+00
# max       9.500000e+01
# count     7.200000e+01
# std       2.383674e+01
# var       5.681901e+02
# prod     1.317922e+104
# Name: team2_fifa_rank, dtype: float64

# %%
## sorting data in data frames

# - df.sort_value(by = 'colummn')
# - df.sort_index()

# %%
## Aggregation

# -

# %%
df = pd.read_csv("wc_2026.csv")

df.team1_fifa_rank.max()
# Out:
# 95.0

# %%
df.team1_fifa_rank.min()

df[["team1_fifa_rank","team2_fifa_rank" ]].min()
df[["team1_fifa_rank","team2_fifa_rank" ]].max()
df[["team1_fifa_rank","team2_fifa_rank" ]].mean()
df[["team1_fifa_rank","team2_fifa_rank" ]].median()


# df[["team1_fifa_rank","team2_fifa_rank" ]].mode()
# Out:
# team1_fifa_rank    24.0
# team2_fifa_rank    35.5
# dtype: float64

# %%
df[["team1_fifa_rank","team2_fifa_rank" ]].mean(axis= 0)
# Out:
# team1_fifa_rank    30.208333
# team2_fifa_rank    37.916667
# dtype: float64

# %%
df[(df["team1_fifa_rank"] <5) | (df["team2_fifa_rank"] <5)]
# Out:
#    group        stage      team1         team2                    venue  \
# 42     H  Group Stage      Spain    Cape Verde    Mercedes-Benz Stadium
# 44     H  Group Stage      Spain  Saudi Arabia            Estadio Akron
# 47     H  Group Stage    Uruguay         Spain            Estadio Akron
# 48     I  Group Stage     France       Senegal          MetLife Stadium
# 50     I  Group Stage     France          Iraq  Lincoln Financial Field
# 52     I  Group Stage     Norway        France          MetLife Stadium
# 54     J  Group Stage  Argentina       Algeria        Arrowhead Stadium
# 56     J  Group Stage  Argentina       Austria             AT&T Stadium
# 59     J  Group Stage     Jordan     Argentina             AT&T Stadium
# 66     L  Group Stage    England       Croatia             AT&T Stadium
# 68     L  Group Stage    England         Ghana         Gillette Stadium
# 70     L  Group Stage     Panama       England          MetLife Stadium
#
# ...

# %%
df_emp = pd.read_csv("employee.csv")
df_emp
# Out:
#       Name   Department  Salary  Experience
# 0    Alice  Engineering   75000           3
# 1      Bob    Marketing   65000           5
# 2  Charlie  Engineering   80000           7
# 3    Diana           HR   60000           2
# 4      Eve    Marketing   70000           4

# %%
## NUMPY

# - In NumPy (arrays), axis refers to dimensions of an array:

# - axis = 0 → column-wise (down the rows)
# - axis = 1 → row-wise (across columns)


## PANDAS

# - In Pandas, axis works similarly but is tied to rows and columns in a DataFrame:

# - axis = 0 → operate down the rows (column-wise operation)
# - axis = 1 → operate across columns (row-wise operation)


### DROP ARGUMENT:

# - df.drop(axis = 0) # drop rows / vertical
# - df.drop(axis = 1) # drop columns / horizontal

# %%
df_emp[['Salary', 'Experience']].mean(axis = 0) # column-wise
# Out:
# Salary        70000.0
# Experience        4.2
# dtype: float64

# %%
df_emp[['Salary', 'Experience']].mean(axis = 1) # row-wise
# Out:
# 0    37501.5
# 1    32502.5
# 2    40003.5
# 3    30001.0
# 4    35002.0
# dtype: float64

# %%
df_emp.drop("Name", axis = 1) # targetting the header & its column
# Out:
#     Department  Salary  Experience
# 0  Engineering   75000           3
# 1    Marketing   65000           5
# 2  Engineering   80000           7
# 3           HR   60000           2
# 4    Marketing   70000           4

# %%
df_emp.drop("Department", axis = 1) # targetting the header & its column
# Out:
#       Name  Salary  Experience
# 0    Alice   75000           3
# 1      Bob   65000           5
# 2  Charlie   80000           7
# 3    Diana   60000           2
# 4      Eve   70000           4

# %%
## to drop all missing values

df.dropna()
# Out:
#    group        stage        team1         team2             venue  \
# 0      A  Group Stage       Mexico  South Africa    Estadio Azteca
# 1      A  Group Stage  South Korea       Czechia     Estadio Akron
# 2      A  Group Stage  South Korea        Mexico     Estadio Akron
# 3      A  Group Stage      Czechia  South Africa     Estadio Akron
# 4      A  Group Stage      Czechia        Mexico    Estadio Azteca
# ..   ...          ...          ...           ...               ...
# 67     L  Group Stage        Ghana        Panama         BMO Field
# 68     L  Group Stage      England         Ghana  Gillette Stadium
# 69     L  Group Stage      Croatia        Panama         BMO Field
# 70     L  Group Stage       Panama       England   MetLife Stadium
# 71     L  Group Stage      Croatia         Ghana   MetLife Stadium
#
#                city country        date kickoff_et team1_confederation  \
# 0       Mexico City  Mexico  2026-06-11   20:00 ET            CONCACAF
# ...

# %%
## to drop all missing values

df.dropna(inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72 entries, 0 to 71
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   group                72 non-null     object
#  1   stage                72 non-null     object
#  2   team1                72 non-null     object
#  3   team2                72 non-null     object
#  4   venue                72 non-null     object
#  5   city                 72 non-null     object
#  6   country              72 non-null     object
#  7   date                 72 non-null     object
#  8   kickoff_et           72 non-null     object
#  9   team1_confederation  72 non-null     object
#  10  team1_fifa_rank      72 non-null     float64
#  11  team1_coach          72 non-null     object
#  12  team2_confederation  72 non-null     object
#  13  team2_fifa_rank      72 non-null     float64
#  14  team2_coach          72 non-null     object
# ...

# %%
# min for each column : column-wise

df[['team1_fifa_rank', 'team2_fifa_rank']].min(axis=0)
# Out:
# team1_fifa_rank    1.0
# team2_fifa_rank    1.0
# dtype: float64

# %%
# min between two columns : row-wise

df[['team1_fifa_rank', 'team2_fifa_rank']].min(axis=1)
# Out:
# 0     15.0
# 1     25.0
# 2     15.0
# 3     41.0
# 4     15.0
#       ...
# 67    53.0
# 68     4.0
# 69    11.0
# 70     4.0
# 71    11.0
# Length: 72, dtype: float64

# %%
## aggregates

# %%
### GROUPING

# - group the data by some category
# - using df.groupby('category').count() : will give the full columns / dataset
# using df.groupby('category').size() : will only give the total counts for respective category

# %%
df_emp.head()
# Out:
#       Name   Department  Salary  Experience
# 0    Alice  Engineering   75000           3
# 1      Bob    Marketing   65000           5
# 2  Charlie  Engineering   80000           7
# 3    Diana           HR   60000           2
# 4      Eve    Marketing   70000           4

# %%
df_emp.groupby("Department")[["Name", "Salary", "Experience"]].count()
# Out:
#              Name  Salary  Experience
# Department
# Engineering     2       2           2
# HR              1       1           1
# Marketing       2       2           2

# %%
df_emp.groupby("Department")[["Name", "Salary", "Experience"]].min()
# Out:
#               Name  Salary  Experience
# Department
# Engineering  Alice   75000           3
# HR           Diana   60000           2
# Marketing      Bob   65000           4

# %%
df.groupby("country").count() # using df.groupby('category').count() : will give the full columns / dataset
# Out:
#          group  stage  team1  team2  venue  city  date  kickoff_et  \
# country
# Canada       7      7      7      7      7     7     7           7
# Mexico      12     12     12     12     12    12    12          12
# USA         53     53     53     53     53    53    53          53
#
#          team1_confederation  team1_fifa_rank  team1_coach  \
# country
# Canada                     7                7            7
# Mexico                    12               12           12
# USA                       53               53           53
#
#          team2_confederation  team2_fifa_rank  team2_coach
# country
# Canada                     7                7            7
# Mexico                    12               12           12
# USA                       53               53           53

# %%
df.groupby("country").size() # using df.groupby('category').size() : will only give the total counts for respective category
# Out:
# country
# Canada     7
# Mexico    12
# USA       53
# dtype: int64

# %%
### COMBINING DATAFRAMES

# JOINS : used to combine two tables

# %%
df_student = pd.read_csv("student_marks.csv")

# %%
### MATPLOTLIB
