# %% [markdown]
# ## Subplots
# - are combination of multiple visualizations

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create a dataset for comparison
data = pd.DataFrame({
    'Age': [23, 45, 34, 42, 25, 36, 52, 39, 40, 30],
    'Salary': [40000, 80000, 60000, 75000, 42000, 62000, 95000, 71000, 85000, 53000]
})

# Scatter Plot of Age vs Salary
sns.scatterplot(x=data['Age'], y=data['Salary'], color='purple')
plt.title('Age vs Salary (Scatter Plot)')
plt.show()

# Histogram of Age
sns.histplot(data['Age'], bins=5, kde=True, color='green')
plt.title('Histogram of Age')
plt.show()

# Box Plot of Salary
sns.boxplot(data['Salary'], color='orange')
plt.title('Box Plot of Salary')
plt.show()

# %%
### SUBPLOTS

# Create a figure with 1 row and 3 columns
plt.figure(figsize=(15, 5)) # This creates a figure with a specific size, here 15 inches wide and 5 inches tall, to accommodate three plots side by side.

# Scatter Plot (1st subplot)
plt.subplot(1, 3, 1)  # (rows, columns, position)
sns.scatterplot(x=data['Age'], y=data['Salary'], color='purple')
plt.title('Age vs Salary (Scatter Plot)')
plt.xlabel('Age')
plt.ylabel('Salary')

# Histogram (2nd subplot)
plt.subplot(1, 3, 2)  # (rows, columns, position)
sns.histplot(data['Age'], bins=5, kde=True, color='green')
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')

# Box Plot (3rd subplot)
plt.subplot(1, 3, 3)  # (rows, columns, position)
sns.boxplot(data['Salary'], color='orange')
plt.title('Box Plot of Salary')
plt.xlabel('Salary')

# Adjust layout to avoid overlap
plt.tight_layout()

# Show the plots
plt.show()

# %%
fig, ax = plt.subplots(1,3, figsize = (12, 5)) # creates a canvas

sns.scatterplot(x=data['Age'], y=data['Salary'], color='purple', ax = ax[0])
ax[0].set_title('Age vs Salary (Scatter Plot)')
ax[0].set_xlabel('Age')
ax[0].set_ylabel('Salary')

sns.histplot(data['Age'], bins=5, kde=True, color='green', ax = ax[1])
ax[1].set_title('Age Distribution (Histogram)')
ax[1].set_xlabel('Age')
ax[1].set_ylabel('Frequency')

sns.boxplot(data['Salary'], color='orange', ax = ax[2])
ax[2].set_title('Salary Distribution (Box Plot)')
ax[2].set_xlabel('Salary')
ax[2].set_ylabel('Salary')


plt.suptitle("Salary and Age Dashboard", 
             fontsize = 24,
             fontweight = 'bold',
             y = 1.03)

plt.tight_layout() # prevents overlaps

# %%
fig, ax = plt.subplots(2,3, figsize = (12, 7)) # creates a canvas

sns.set_theme(style= 'darkgrid', 
              palette= 'pastel', #'pastel',
              font= 'sans-serif',
              font_scale= 1.1,)

sns.scatterplot(x=data['Age'], y=data['Salary'], ax = ax[0,0])
ax[0,0].set_title('Age vs Salary (Scatter Plot)')
ax[0,0].set_xlabel('Age')
ax[0,0].set_ylabel('Salary')

sns.histplot(data['Age'], bins=5, kde=True, ax = ax[0,1])
ax[0,1].set_title('Age Distribution (Histogram)')
ax[0,1].set_xlabel('Age')
ax[0,1].set_ylabel('Frequency')

sns.boxplot(data['Salary'], ax = ax[0, 2])
ax[0,2].set_title('Salary Distribution (Box Plot)')
ax[0,2].set_xlabel('Salary')
ax[0,2].set_ylabel('Salary')


plt.suptitle("Salary and Age Dashboard", 
             fontsize = 24,
             fontweight = 'bold',
             y = 1.03)

plt.tight_layout() # prevents overlaps
plt.show()

# %% [markdown]
# ### Assignment:
# - Take the world cup datasheet
# - create a python dashboard
# - create 6 visualization over the data sheet:
#     - scatter - fifa rank team1 vs team 2
#     - line plot - date and team 1 fifa rank
#     - histogram - pie chart - heatmap - jointplot - Box plot
#
# - you are free to choose what visuals you want to make
# - if you cannot find good visual ideas/ story for this dataset, choose your own one
#     - house price
#     - titanic
#     - netflix datasets
#     - imdb datasets
#     - environmental

# %%
df = pd.read_csv('wc_2026.csv')
df.head()
# Out:
#   group        stage        team1         team2           venue         city  \
# 0     A  Group Stage       Mexico  South Africa  Estadio Azteca  Mexico City
# 1     A  Group Stage  South Korea       Czechia   Estadio Akron  Guadalajara
# 2     A  Group Stage  South Korea        Mexico   Estadio Akron  Guadalajara
# 3     A  Group Stage      Czechia  South Africa   Estadio Akron  Guadalajara
# 4     A  Group Stage      Czechia        Mexico  Estadio Azteca  Mexico City
#
#   country        date kickoff_et team1_confederation  team1_fifa_rank  \
# 0  Mexico  2026-06-11   20:00 ET            CONCACAF             15.0
# 1  Mexico  2026-06-11   22:00 ET                 AFC             25.0
# 2  Mexico  2026-06-18   21:00 ET                 AFC             25.0
# 3  Mexico  2026-06-18   18:00 ET                UEFA             41.0
# 4  Mexico  2026-06-24   21:00 ET                UEFA             41.0
#
#       team1_coach team2_confederation  team2_fifa_rank     team2_coach
# 0  Javier Aguirre                 CAF             60.0      Hugo Broos
# 1   Hong Myung-bo                UEFA             41.0      Ivan Hasek
# 2   Hong Myung-bo            CONCACAF             15.0  Javier Aguirre
# 3      Ivan Hasek                 CAF             60.0      Hugo Broos
# 4      Ivan Hasek            CONCACAF             15.0  Javier Aguirre

# %%
# plt.plot(df['date'])
sns.lineplot(data = df, x= "date", y ="team1_fifa_rank")
plt.xticks(rotation = 45)
plt.show()

# %%
## Solution

import pandas as pd

df = pd.read_csv("wc_2026.csv")

print(df.head())
print(df.columns.tolist())
print(df.info())
# Out:
#   group        stage        team1         team2           venue         city  \
# 0     A  Group Stage       Mexico  South Africa  Estadio Azteca  Mexico City
# 1     A  Group Stage  South Korea       Czechia   Estadio Akron  Guadalajara
# 2     A  Group Stage  South Korea        Mexico   Estadio Akron  Guadalajara
# 3     A  Group Stage      Czechia  South Africa   Estadio Akron  Guadalajara
# 4     A  Group Stage      Czechia        Mexico  Estadio Azteca  Mexico City
#
#   country        date kickoff_et team1_confederation  team1_fifa_rank  \
# 0  Mexico  2026-06-11   20:00 ET            CONCACAF             15.0
# 1  Mexico  2026-06-11   22:00 ET                 AFC             25.0
# 2  Mexico  2026-06-18   21:00 ET                 AFC             25.0
# 3  Mexico  2026-06-18   18:00 ET                UEFA             41.0
# 4  Mexico  2026-06-24   21:00 ET                UEFA             41.0
#
#       team1_coach team2_confederation  team2_fifa_rank     team2_coach
# 0  Javier Aguirre                 CAF             60.0      Hugo Broos
# 1   Hong Myung-bo                UEFA             41.0      Ivan Hasek
# 2   Hong Myung-bo            CONCACAF             15.0  Javier Aguirre
# 3      Ivan Hasek                 CAF             60.0      Hugo Broos
# 4      Ivan Hasek            CONCACAF             15.0  Javier Aguirre
# ['group', 'stage', 'team1', 'team2', 'venue', 'city', 'country', 'date', 'kickoff_et', 'team1_confederation', 'team1_fifa_rank', 'team1_coach', 'team2_confederation', 'team2_fifa_rank', 'team2_coach']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   group                72 non-null     object
#  1   stage                104 non-null    object
#  2   team1                104 non-null    object
#  3   team2                104 non-null    object
#  4   venue                104 non-null    object
#  5   city                 104 non-null    object
#  6   country              104 non-null    object
#  7   date                 104 non-null    object
#  8   kickoff_et           104 non-null    object
#  9   team1_confederation  72 non-null     object
#  10  team1_fifa_rank      72 non-null     float64
#  11  team1_coach          72 non-null     object
#  12  team2_confederation  72 non-null     object
#  13  team2_fifa_rank      72 non-null     float64
#  14  team2_coach          72 non-null     object
# dtypes: float64(2), object(13)
# memory usage: 12.3+ KB
# None

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("wc_2026.csv")
df['date'] = pd.to_datetime(df['date'])

fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# 1 Scatter Plot
sns.scatterplot(
    data=df,
    x='team1_fifa_rank',
    y='team2_fifa_rank',
    ax=axes[0,0]
)
axes[0,0].set_title("Team1 vs Team2 FIFA Rank")

# 2 Line Plot
sns.lineplot(
    data=df,
    x='date',
    y='team1_fifa_rank',
    ax=axes[0,1]
)
axes[0,1].set_title("Team1 FIFA Rank Over Time")
axes[0,1].tick_params(axis='x', rotation=45)

# 3 Histogram
sns.histplot(
    df['team1_fifa_rank'],
    bins=15,
    kde=True,
    ax=axes[0,2]
)
axes[0,2].set_title("Distribution of Team1 FIFA Rank")

# 4 Box Plot
sns.boxplot(
    data=df[['team1_fifa_rank', 'team2_fifa_rank']],
    ax=axes[1,0]
)
axes[1,0].set_title("FIFA Rank Distribution Comparison")

# 5 Heatmap
cols = ['team1_fifa_rank', 'team2_fifa_rank']

sns.heatmap(
    df[cols].corr(),
    annot=True,
    cmap='coolwarm',
    ax=axes[1,1]
)
axes[1,1].set_title("Correlation Heatmap")

# 6 Pie Chart
df['team1_confederation'].value_counts().plot.pie(
    autopct='%1.1f%%',
    ax=axes[1,2]
)
axes[1,2].set_title("Team1 Confederation Distribution")
axes[1,2].set_ylabel("")

plt.tight_layout()
plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['group', 'stage', 'team1', 'team2', 'venue', 'city', 'country', 'date', 'kickoff_et', 'team1_confederation', 'team1_fifa_rank', 'team1_coach', 'team2_confederation', 'team2_fifa_rank', 'team2_coach']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-v0_8')

df = pd.read_csv("wc_2026.csv")
df['date'] = pd.to_datetime(df['date'])

fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# 1 Scatter Plot
sns.scatterplot(
    data=df,
    x='team1_fifa_rank',
    y='team2_fifa_rank',
    ax=axes[0,0]
)
axes[0,0].set_title("Team1 vs Team2 FIFA Rank")

# 2 Line Plot
sns.lineplot(
    data=df,
    x='date',
    y='team1_fifa_rank',
    ax=axes[0,1]
)
axes[0,1].set_title("Team1 FIFA Rank Over Time")
axes[0,1].tick_params(axis='x', rotation=45)

# 3 Histogram
sns.histplot(
    df['team1_fifa_rank'],
    bins=15,
    kde=True,
    ax=axes[0,2]
)
axes[0,2].set_title("Distribution of Team1 FIFA Rank")

# 4 Box Plot
sns.boxplot(
    data=df[['team1_fifa_rank', 'team2_fifa_rank']],
    ax=axes[1,0]
)
axes[1,0].set_title("FIFA Rank Distribution Comparison")

# 5 Heatmap
cols = ['team1_fifa_rank', 'team2_fifa_rank']

sns.heatmap(
    df[cols].corr(),
    annot=True,
    cmap='coolwarm',
    ax=axes[1,1]
)
axes[1,1].set_title("Correlation Heatmap")

# 6 Pie Chart
df['team1_confederation'].value_counts().plot.pie(
    autopct='%1.1f%%',
    ax=axes[1,2]
)
axes[1,2].set_title("Team1 Confederation Distribution")
axes[1,2].set_ylabel("")

plt.tight_layout()
plt.show()
